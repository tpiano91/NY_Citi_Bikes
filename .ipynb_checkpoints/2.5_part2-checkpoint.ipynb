# %%
import pandas as pd
import os
from keplergl import KeplerGl
from pyproj import CRS
import numpy as np
from matplotlib import pyplot as plt

# %%
pip install keplergl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 54.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#   Created wheel for keplergl: filename=keplergl-0.3.2-py2.py3-none-any.whl size=17922317 sha256=e50a1020980d9cf2de1f1dc302d1b0143e00731526d0a2d2e7c4de569ae9fe54
#   Stored in directory: /root/.cache/pip/wheels/e5/e9/db/b8b8f2fcb5cb1cd7268d88959fce267bc00697cb8f50dcd0d9
# Successfully built keplergl
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/NY_Citi_Bikes/Data/trip_locations.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 origin                        destination  \
# 0           0  11 St & Washington St              11 St & Washington St
# 1           1  11 St & Washington St                   12 Ave & W 40 St
# 2           2  11 St & Washington St               12 St & Sinatra Dr N
# 3           3  11 St & Washington St  14 St Ferry - 14 St & Shipyard Ln
# 4           4  11 St & Washington St                    4 St & Grand St
#
#    trips  start_lat  start_lng    end_lat    end_lng
# 0   1132  40.749985  -74.02715  40.749985 -74.027150
# 1      1  40.749985  -74.02715  40.760875 -74.002777
# 2    253  40.749985  -74.02715  40.750604 -74.024020
# 3    395  40.749985  -74.02715  40.752961 -74.024353
# 4    350  40.749985  -74.02715  40.742258 -74.035111

# %%
# Create KeplerGl instance

m = KeplerGl(height = 700, data={"data_1": df})
m
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_1':       Unnamed: 0                 origin                        destination  \
# 0      …

# %% [markdown]
# All of the popular bike trips seem to be are in Jersey City, with many origin/destination combinations having thousands of trips in 2022.

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
config = m.config

# %%
config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [],
#    'layers': [{'id': 'gn8aei',
#      'type': 'point',
#      'config': {'dataId': 'data_1',
#       'label': 'start',
#       'color': [18, 147, 154],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'start_lat', 'lng': 'start_lng', 'altitude': None},
#       'isVisible': True,
#       'visConfig': {'radius': 10,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'ColorBrewer Greens-6',
#         'type': 'singlehue',
#         'category': 'ColorBrewer',
#         'colors': ['#edf8e9',
#          '#c7e9c0',
#          '#a1d99b',
#          '#74c476',
#          '#31a354',
#          '#006d2c']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
# ...

# %%
import json
with open("/content/drive/MyDrive/NY_Citi_Bikes/config.json", "w") as outfile:
    json.dump(config, outfile)

# %%
m.save_to_html(file_name = 'NYC_Citi_Bikes_Map.html', read_only = False, config = config)
# Out:
# Map saved to NYC_Citi_Bikes_Map.html!

# %%
from google.colab import files
files.download('NYC_Citi_Bikes_Map.html')
